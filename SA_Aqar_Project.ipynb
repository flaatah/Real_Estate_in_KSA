# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# !pip install python-bidi
# !pip install arabic-reshaper
import arabic_reshaper
from bidi.algorithm import get_display
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.read_csv('SA_Aqar.csv')

# %%
def f(x):
    out=get_display( arabic_reshaper.reshape(x))
    return(out)

# %%
df.head()
# Out:
#       city         district front  size  property_age  bedrooms  bathrooms  \
# 0  ﺽﺎﻳﺮﻟﺍ        حي العارض   ﻝﺎﻤﺷ   250             0         5          5
# 1  ﺽﺎﻳﺮﻟﺍ      حي القادسية   ﺏﻮﻨﺟ   370             0         4          5
# 2  ﺽﺎﻳﺮﻟﺍ      حي القادسية   ﺏﻮﻨﺟ   380             0         4          5
# 3  ﺽﺎﻳﺮﻟﺍ      حي المعيزلة    ﺏﺮﻏ   250             0         5          5
# 4  ﺽﺎﻳﺮﻟﺍ        حي العليا    ﺏﺮﻏ   400            11         7          5
#
#    livingrooms  kitchen  garage  ...  roof  pool  frontyard  basement  duplex  \
# 0            1        1       1  ...     0     0          1         0       1
# 1            2        1       1  ...     0     0          1         0       0
# 2            1        1       1  ...     1     0          1         0       0
# 3            3        0       1  ...     0     0          1         0       0
# 4            2        1       1  ...     1     0          1         0       1
#
#    stairs  elevator  fireplace  price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3718 entries, 0 to 3717
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city          3718 non-null   object
#  1   district      3718 non-null   object
#  2   front         3718 non-null   object
#  3   size          3718 non-null   int64
#  4   property_age  3718 non-null   int64
#  5   bedrooms      3718 non-null   int64
#  6   bathrooms     3718 non-null   int64
#  7   livingrooms   3718 non-null   int64
#  8   kitchen       3718 non-null   int64
#  9   garage        3718 non-null   int64
#  10  driver_room   3718 non-null   int64
#  11  maid_room     3718 non-null   int64
#  12  furnished     3718 non-null   int64
#  13  ac            3718 non-null   int64
#  14  roof          3718 non-null   int64
#  15  pool          3718 non-null   int64
#  16  frontyard     3718 non-null   int64
#  17  basement      3718 non-null   int64
# ...

# %%
df.describe().transpose()
# Out:
#                count          mean           std     min      25%      50%  \
# size          3718.0    390.968531   1565.056135     1.0    280.0    330.0
# property_age  3718.0      5.064820      7.590427     0.0      0.0      2.0
# bedrooms      3718.0      5.083916      1.230040     1.0      4.0      5.0
# bathrooms     3718.0      4.606509      0.703449     1.0      4.0      5.0
# livingrooms   3718.0      2.243948      0.916436     1.0      2.0      2.0
# kitchen       3718.0      0.909360      0.287135     0.0      1.0      1.0
# garage        3718.0      0.802044      0.398512     0.0      1.0      1.0
# driver_room   3718.0      0.495697      0.500049     0.0      0.0      0.0
# maid_room     3718.0      0.795320      0.403522     0.0      1.0      1.0
# furnished     3718.0      0.123453      0.329001     0.0      0.0      0.0
# ac            3718.0      0.560785      0.496358     0.0      0.0      1.0
# ...

# %%
plt.figure(figsize=(15,5),dpi=100)
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')

# %%
plt.figure(figsize=(10,5), dpi=100)
df.corr()['price'].iloc[:-1].sort_values().plot(kind='bar')

# %%
plt.figure(figsize=(10,5),dpi=100)
plt.ticklabel_format(style='plain', axis='y')
sns.boxplot(data=df, x='driver_room', y='price')

# %%
df['city']=df['city'].apply(f)

# %%
plt.figure(figsize=(10,5),dpi=100)
plt.ticklabel_format(style='plain', axis='y')
sns.boxplot(data=df, x=df['city'], y='price')

# %%
df['front']=df['front'].apply(f)
plt.figure(figsize=(10,5),dpi=100)
plt.ticklabel_format(style='plain', axis='y')
sns.boxplot(data=df, x='front', y='price')
plt.xticks(rotation=90);

# %%
df['driver_room'].max()
df[df['driver_room']==1].sort_values('driver_room', ascending=False)
# Out:
#          city                  district front  size  property_age  bedrooms  \
# 2     ﺽﺎﻳﺮﻟﺍ               حي القادسية   ﺏﻮﻨﺟ   380             0         4
# 2140  ﻡﺎﻣﺪﻟﺍ                حي المنتزه    ﺏﺮﻏ   387             0         5
# 2135  ﻡﺎﻣﺪﻟﺍ      حي الخالدية الشمالية    ﻕﺮﺷ   400             5         7
# 2133  ﻡﺎﻣﺪﻟﺍ                 حي الشعلة   ﺏﻮﻨﺟ   300             3         4
# 2132  ﻡﺎﻣﺪﻟﺍ                  حي السيف    ﺏﺮﻏ   300            11         6
# ...       ...                       ...   ...   ...           ...       ...
# 1126     ﺓﺪﺟ                حي السلامة   ﺏﻮﻨﺟ     1             5         5
# 1124     ﺓﺪﺟ                حي الصوارى    ﺏﺮﻏ   200             7         7
# 1123     ﺓﺪﺟ                حي الياقوت    ﺏﺮﻏ   262             2         6
# 1122     ﺓﺪﺟ                حي الصوارى   ﺏﻮﻨﺟ   290             0         5
# 3716   ﺮﺒﺨﻟﺍ               حي الكورنيش   ﺏﻮﻨﺟ   300            13         6
#
# ...

# %%
plt.figure(figsize=(10,5),dpi=100)
plt.ticklabel_format(style='plain', axis='x')
sns.boxplot(data=df, x='price')

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.histplot(data=df, x='price', bins=50)
plt.ticklabel_format(style='plain', axis='x')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,5),dpi=100)

plt.ticklabel_format(style='plain', axis='x')
sns.scatterplot(data=df, x='price', y='size')

# %%
df['property_age'].unique()
# Out:
# array([ 0, 11, 25,  6, 20, 28,  9, 10, 18, 13,  5, 12,  3,  7,  2,  8, 30,
#         4, 27, 15, 35, 19, 33, 14, 21, 26, 36, 16, 29, 23, 32, 17, 24, 34,
#        22, 31])

# %%
plt.figure(figsize=(10,3),dpi=100)
sns.countplot(df['property_age'].sort_values());
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,3),dpi=100)
plt.ticklabel_format(style='plain', axis='y')
sns.boxplot(data=df, x='furnished', y='price')

# %%
plt.figure(figsize=(10,3),dpi=100)
plt.ticklabel_format(style='plain', axis='y')
sns.scatterplot(data=df, x='property_age', y='price', hue='driver_room')

# %%
plt.figure(figsize=(10,3),dpi=100)
plt.ticklabel_format(style='plain', axis='y')
sns.boxplot(data=df, x='pool', y='price')
